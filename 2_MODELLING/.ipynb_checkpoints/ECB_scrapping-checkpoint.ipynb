# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd

ecb_url = 'https://www.ecb.europa.eu/press/pr/activities/mopo/html/index.en.html'

response = requests.get(ecb_url)

if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')

    div_elements = soup.find_all('div', class_='title')

    data_list = []  # Create an empty list to store statement data

    for div in div_elements:
        statement_links = div.find_all('a', text=lambda text: "Monetary policy decisions" in text)
        date_element = div.find_previous('dt')  # Find the corresponding date element
        if date_element:
            date = date_element.find('div', class_='date').text.strip()
        else:
            date = "N/A"

        for link in statement_links:
            statement_url = urljoin(ecb_url, link['href'])

            # Fetch the content of the statement URL
            statement_response = requests.get(statement_url)

            if statement_response.status_code == 200:
                statement_soup = BeautifulSoup(statement_response.content, 'html.parser')
                section_div = statement_soup.find('main')

                statement_content = section_div.get_text()
                data_list.append([date, statement_url, statement_content])
            else:
                print(f"Failed to retrieve the content of statement URL: {statement_url}")
else:
    print("Failed to retrieve the ECB webpage.")

# Convert the list of lists into a DataFrame with appropriate column names
result_df = pd.DataFrame(data_list, columns=['date', 'statement_url', 'statement_content'])

# Print the resulting DataFrame
print(result_df)
# Out:
# <ipython-input-88-1112e4164eec>:18: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   statement_links = div.find_all('a', text=lambda text: "Monetary policy decisions" in text)
#                   date                                      statement_url  \
# 0      26 October 2023  https://www.ecb.europa.eu/press/pr/date/2023/h...
# 1    14 September 2023  https://www.ecb.europa.eu/press/pr/date/2023/h...
# 2         27 July 2023  https://www.ecb.europa.eu/press/pr/date/2023/h...
# 3         27 July 2023  https://www.ecb.europa.eu/press/pr/date/2023/h...
# 4         15 June 2023  https://www.ecb.europa.eu/press/pr/date/2023/h...
# ..                 ...                                                ...
# 294         6 May 1999  https://www.ecb.europa.eu/press/pr/date/1999/h...
# 295      22 April 1999  https://www.ecb.europa.eu/press/pr/date/1999/h...
# 296       8 April 1999  https://www.ecb.europa.eu/press/pr/date/1999/h...
# ...

# %%
print (result_df.statement_content[298])
# Out:
#   PRESS RELEASE
#
#
# Monetary policy decisions
#
#
#   4 March 1999
#
#
# At today's meeting the Governing Council reviewed the latest monetary, financial and economic developments. Taking into account all the information available, the Governing Council confirmed its earlier assessment of the outlook for price stability. Against this background it decided that for the main refinancing operations to be settled on 10 and 17 March 1999 the same conditions will apply as for the previous ones, i.e. they will be conducted as fixed rate tenders at an interest rate of 3.0%. In addition, the interest rate on the marginal lending facility will continue to be 4.5% and the interest rate on the deposit facility will remain 2.0%.
# ...

# %%
# Out:
# <ipython-input-114-27f6f87d5e8f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Len'][i]=(len(df['DEC_CON'][i]))

# %%
df.to_excel('/DATA/df.xlsx')

# %%
print(result_df.statement_content1[0])
# Out:
#                                  You may also be interested in:Monetary policy statement (with Q&A)View pagePRESS RELEASEMonetary policy decisions26 October 2023 The Governing Council today decided to keep the three key ECB interest rates unchanged. The incoming information has broadly confirmed its previous assessment of the medium-term inflation outlook. Inflation is still expected to stay too high for too long, and domestic price pressures remain strong. At the same time, inflation dropped markedly in September, including due to strong base effects, and most measures of underlying inflation have continued to ease. The Governing Council’s past interest rate increases continue to be transmitted forcefully into financing conditions. This is increasingly dampening demand and thereby helps push down inflation. The Governing Council is determined to ensure that inflation returns to its 2% medium-term target in a timely manner. Based on its current assessment, the Governing Council consi
# ...

# %%
# Out:
# <ipython-input-3-33c82b7168a5>:18: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   statement_links = div.find_all('a', text=lambda text: "Monetary policy decisions" in text)
#                   date                                      statement_url  \
# 0      26 October 2023  https://www.ecb.europa.eu/press/pr/date/2023/h...
# 1    14 September 2023  https://www.ecb.europa.eu/press/pr/date/2023/h...
# 2         27 July 2023  https://www.ecb.europa.eu/press/pr/date/2023/h...
# 3         27 July 2023  https://www.ecb.europa.eu/press/pr/date/2023/h...
# 4         15 June 2023  https://www.ecb.europa.eu/press/pr/date/2023/h...
# ..                 ...                                                ...
# 294         6 May 1999  https://www.ecb.europa.eu/press/pr/date/1999/h...
# 295      22 April 1999  https://www.ecb.europa.eu/press/pr/date/1999/h...
# 296       8 April 1999  https://www.ecb.europa.eu/press/pr/date/1999/h...
# ...

# %%
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# 145
# 42
# 20
# 4
# 16
# 37
# 58
# 89
# 145
# 42
# 20
# 4
# 16
# 37
# 58
# 89
# 145
# 42
# 20
# 4
# 16
# 37
# 58
# 89
# 145
# 42
# 20
# 4
# 16
# 37
# 58
# 89
# 145
# 42
# 20
# 4
# 16
# 37
# 58
# 89
# 145
# 42
# 20
# 4
# 16
# 37
# 58
# 89
# 145
# 42
# 20
# 4
# 16
# 37
# 58
# 89
# 145
# 42
# 20
# 4
# 16
# 37
# 58
# 89
# 145
# 42
# 20
# 4
# 16
# 37
# 58
# 89
# 145
# 42
# 20
# 4
# 16
# 37
# 58
# 89
# 145
# 42
# 20
# 4
# 16
# 37
# 58
# 89
# 145
# 42
# 20
# 4
# 16
# 37
# 58
# 89
# 145
# 42
# 20
# 4
# 16
# 37
# 58
# 89
# 145
# 42
# 20
# 4
# 16
# 37
# 58
# 89
# 145
# 42
# 20
# 4
# 16
# 37
# 58
# 89
# 145
# 42
# 20
# 4
# 16
# 37
# 58
# 89
# 145
# 42
# 20
# 4
# 16
# 37
# 58
# 89
# 145
# 42
# 20
# 4
# 16
# 37
# 58
# 89
# 145
# 42
# 20
# 4
# 16
# 37
# 58
# 89
# 145
# 42
# 20
# 4
# 16
# 37
# 58
# 89
# 145
# 42
# 20
# 4
# 16
# 37
# 58
# 89
# 145
# 42
# 20
# 4
# 16
# 37
# 58
# 89
# 145
# 42
# 20
# 4
# 16
# 37
# 58
# 89
# ...
